# %%
import pandas as pd

# %%
df1=pd.read_csv("musk_csv.csv")

# %%
df1.head()
# Out:
#    ID molecule_name conformation_name  f1   f2   f3  f4   f5  f6  f7  ...  \
# 0   1      MUSK-211           211_1+1  46 -108  -60 -69 -117  49  38  ...
# 1   2      MUSK-211          211_1+10  41 -188 -145  22 -117  -6  57  ...
# 2   3      MUSK-211          211_1+11  46 -194 -145  28 -117  73  57  ...
# 3   4      MUSK-211          211_1+12  41 -188 -145  22 -117  -7  57  ...
# 4   5      MUSK-211          211_1+13  41 -188 -145  22 -117  -7  57  ...
#
#    f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  -308    52    -7    39   126   156   -50  -112    96      1
# 1   -59    -2    52   103   136   169   -61  -136    79      1
# 2  -134  -154    57   143   142   165   -67  -145    39      1
# 3   -60    -4    52   104   136   168   -60  -135    80      1
# 4   -60    -4    52   104   137   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6598 entries, 0 to 6597
# Columns: 170 entries, ID to class
# dtypes: int64(168), object(2)
# memory usage: 8.6+ MB

# %%
df1.describe()
# Out:
#                ID           f1           f2           f3           f4  \
# count  6598.00000  6598.000000  6598.000000  6598.000000  6598.000000
# mean   3299.50000    58.945135  -119.128524   -73.146560    -0.628372
# std    1904.82287    53.249007    90.813375    67.956235    80.444617
# min       1.00000   -31.000000  -199.000000  -167.000000  -114.000000
# 25%    1650.25000    37.000000  -193.000000  -137.000000   -70.000000
# 50%    3299.50000    44.000000  -149.000000   -99.000000   -25.000000
# 75%    4948.75000    53.000000   -95.000000   -19.000000    42.000000
# max    6598.00000   292.000000    95.000000    81.000000   161.000000
#
#                 f5           f6           f7           f8           f9  ...  \
# count  6598.000000  6598.000000  6598.000000  6598.000000  6598.000000  ...
# mean   -103.533495    18.359806   -14.108821    -1.858290   -86.003031  ...
# std      64.387559    80.593655   115.315673    90.372537   108.326676  ...
# ...

# %%
df1.isnull().sum()
# Out:
# ID                   0
# molecule_name        0
# conformation_name    0
# f1                   0
# f2                   0
# f3                   0
# f4                   0
# f5                   0
# f6                   0
# f7                   0
# f8                   0
# f9                   0
# f10                  0
# f11                  0
# f12                  0
# f13                  0
# f14                  0
# f15                  0
# f16                  0
# f17                  0
# f18                  0
# f19                  0
# f20                  0
# f21                  0
# f22                  0
# f23                  0
# f24                  0
# f25                  0
# f26                  0
# f27                  0
#                     ..
# f138                 0
# f139                 0
# f140                 0
# f141                 0
# f142                 0
# f143                 0
# f144                 0
# f145                 0
# f146                 0
# ...

# %%
df1[['molecule_name','class']]
# Out:
#       molecule_name  class
# 0          MUSK-211      1
# 1          MUSK-211      1
# 2          MUSK-211      1
# 3          MUSK-211      1
# 4          MUSK-211      1
# 5          MUSK-211      1
# 6          MUSK-211      1
# 7          MUSK-211      1
# 8          MUSK-211      1
# 9          MUSK-211      1
# 10         MUSK-211      1
# 11         MUSK-211      1
# 12         MUSK-211      1
# 13         MUSK-211      1
# 14         MUSK-211      1
# 15         MUSK-211      1
# 16         MUSK-211      1
# 17         MUSK-211      1
# 18         MUSK-211      1
# 19         MUSK-212      1
# 20         MUSK-212      1
# 21         MUSK-212      1
# 22         MUSK-212      1
# 23         MUSK-212      1
# 24         MUSK-212      1
# 25         MUSK-212      1
# 26         MUSK-212      1
# 27         MUSK-212      1
# 28         MUSK-212      1
# 29         MUSK-212      1
# ...             ...    ...
# 6568  NON-MUSK-jp13      0
# 6569  NON-MUSK-jp13      0
# ...

# %%
df1['molecule_name'].nunique()
# Out:
# 102

# %%
df1[["molecule_name","conformation_name"]]
# Out:
#       molecule_name conformation_name
# 0          MUSK-211           211_1+1
# 1          MUSK-211          211_1+10
# 2          MUSK-211          211_1+11
# 3          MUSK-211          211_1+12
# 4          MUSK-211          211_1+13
# 5          MUSK-211          211_1+14
# 6          MUSK-211          211_1+15
# 7          MUSK-211          211_1+16
# 8          MUSK-211          211_1+17
# 9          MUSK-211          211_1+18
# 10         MUSK-211          211_1+19
# 11         MUSK-211           211_1+2
# 12         MUSK-211           211_1+3
# 13         MUSK-211           211_1+4
# 14         MUSK-211           211_1+5
# 15         MUSK-211           211_1+6
# 16         MUSK-211           211_1+7
# 17         MUSK-211           211_1+8
# 18         MUSK-211           211_1+9
# 19         MUSK-212           212_1+1
# 20         MUSK-212          212_1+10
# 21         MUSK-212          212_1+11
# 22         MUSK-212          212_1+12
# 23         MUSK-212          212_1+13
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
plt.figure(figsize=(40,15))
sns.countplot("molecule_name",data=df1)

# %%
df1['class'].value_counts()
# Out:
# 0    5581
# 1    1017
# Name: class, dtype: int64

# %%
df1.columns
# Out:
# Index(['ID', 'molecule_name', 'conformation_name', 'f1', 'f2', 'f3', 'f4',
#        'f5', 'f6', 'f7',
#        ...
#        'f158', 'f159', 'f160', 'f161', 'f162', 'f163', 'f164', 'f165', 'f166',
#        'class'],
#       dtype='object', length=170)

# %%
sns.boxplot(df1['f1'])

# %%
sns.boxplot(df1['f2'])

# %%
sns.boxplot(df1['f3'])

# %%
sns.boxplot(df1['f166'])

# %%
df1['molecule_name']
# Out:
# 0            MUSK-211
# 1            MUSK-211
# 2            MUSK-211
# 3            MUSK-211
# 4            MUSK-211
# 5            MUSK-211
# 6            MUSK-211
# 7            MUSK-211
# 8            MUSK-211
# 9            MUSK-211
# 10           MUSK-211
# 11           MUSK-211
# 12           MUSK-211
# 13           MUSK-211
# 14           MUSK-211
# 15           MUSK-211
# 16           MUSK-211
# 17           MUSK-211
# 18           MUSK-211
# 19           MUSK-212
# 20           MUSK-212
# 21           MUSK-212
# 22           MUSK-212
# 23           MUSK-212
# 24           MUSK-212
# 25           MUSK-212
# 26           MUSK-212
# 27           MUSK-212
# 28           MUSK-212
# 29           MUSK-212
#             ...
# 6568    NON-MUSK-jp13
# 6569    NON-MUSK-jp13
# 6570    NON-MUSK-jp13
# 6571    NON-MUSK-jp13
# 6572    NON-MUSK-jp13
# 6573    NON-MUSK-jp13
# 6574    NON-MUSK-jp13
# 6575    NON-MUSK-jp13
# 6576    NON-MUSK-jp13
# 6577    NON-MUSK-jp13
# ...

# %%
import re

# %%
df1['new']= df1['molecule_name'].apply(lambda x: (re.sub('[A-Z]','',x)))

# %%
df1['new1']= df1['new'].apply(lambda x: (re.sub('-','',x)))

# %%
df1.drop(["new","new1","molecule_name"],axis=1,inplace=True)

# %%
df1['new2']=df1['new1'].apply(lambda x: (re.sub('[a-z]','',x)))

# %%
df1.new2
# Out:
# 0       211
# 1       211
# 2       211
# 3       211
# 4       211
# 5       211
# 6       211
# 7       211
# 8       211
# 9       211
# 10      211
# 11      211
# 12      211
# 13      211
# 14      211
# 15      211
# 16      211
# 17      211
# 18      211
# 19      212
# 20      212
# 21      212
# 22      212
# 23      212
# 24      212
# 25      212
# 26      212
# 27      212
# 28      212
# 29      212
#        ...
# 6568     13
# 6569     13
# 6570     13
# 6571     13
# 6572     13
# 6573     13
# 6574     13
# 6575     13
# 6576     13
# 6577     13
# 6578     13
# 6579     13
# 6580     13
# 6581     13
# 6582     13
# 6583     13
# 6584     13
# 6585     13
# 6586     13
# 6587     13
# 6588     13
# 6589     13
# 6590     13
# 6591     13
# 6592     13
# 6593     13
# 6594     13
# 6595     13
# 6596     13
# 6597     13
# Name: new2, Length: 6598, dtype: object

# %%
df1.new2.astype("int64")
# Out:
# 0       211
# 1       211
# 2       211
# 3       211
# 4       211
# 5       211
# 6       211
# 7       211
# 8       211
# 9       211
# 10      211
# 11      211
# 12      211
# 13      211
# 14      211
# 15      211
# 16      211
# 17      211
# 18      211
# 19      212
# 20      212
# 21      212
# 22      212
# 23      212
# 24      212
# 25      212
# 26      212
# 27      212
# 28      212
# 29      212
#        ...
# 6568     13
# 6569     13
# 6570     13
# 6571     13
# 6572     13
# 6573     13
# 6574     13
# 6575     13
# 6576     13
# 6577     13
# 6578     13
# 6579     13
# 6580     13
# 6581     13
# 6582     13
# 6583     13
# 6584     13
# 6585     13
# 6586     13
# 6587     13
# 6588     13
# 6589     13
# 6590     13
# 6591     13
# 6592     13
# 6593     13
# 6594     13
# 6595     13
# 6596     13
# 6597     13
# Name: new2, Length: 6598, dtype: int64

# %%
df1.columns
# Out:
# Index(['ID', 'f1', 'f2', 'f3', 'f4', 'f5', 'f6', 'f7', 'f8', 'f9',
#        ...
#        'f159', 'f160', 'f161', 'f162', 'f163', 'f164', 'f165', 'f166', 'class',
#        'new2'],
#       dtype='object', length=169)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(df1.drop(["class"],axis=1),df1['class'],random_state=102,test_size=0.2)

# %%
x_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5278 entries, 6111 to 2304
# Columns: 168 entries, ID to new2
# dtypes: int64(167), object(1)
# memory usage: 6.8+ MB

# %%
from sklearn.linear_model import LogisticRegression
lg=LogisticRegression()
lg.fit(x_train, y_train)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
pred_lg=lg.predict(x_test)
from sklearn.metrics import classification_report
from sklearn.metrics import roc_auc_score
print(roc_auc_score(y_test,pred_lg))
print(classification_report(y_test,pred_lg))
lg.score(x_train, y_train)
# Out:
# 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1116
#            1       1.00      1.00      1.00       204
#
#    micro avg       1.00      1.00      1.00      1320
#    macro avg       1.00      1.00      1.00      1320
# weighted avg       1.00      1.00      1.00      1320
# 1.0

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred_lg)
cm
# Out:
# array([[1116,    0],
#        [   0,  204]], dtype=int64)

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(x_train, y_train)
rf_pred=rf.predict(x_test)
print(classification_report(y_test,rf_pred))
rf.score(x_train, y_train)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\sklearn\ensemble\forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1116
#            1       1.00      1.00      1.00       204
#
#    micro avg       1.00      1.00      1.00      1320
#    macro avg       1.00      1.00      1.00      1320
# weighted avg       1.00      1.00      1.00      1320
# 1.0

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,pred_lg)
cm
# Out:
# array([[1116,    0],
#        [   0,  204]], dtype=int64)

# %%
x_train.head()
# Out:
#         ID   f1   f2   f3   f4   f5  f6  f7   f8   f9  ...  f158  f159  f160  \
# 6111  6112   43   85   32  -76 -117  89 -68   53 -216  ...  -282    45     1
# 6539  6540   48 -198 -157   28 -117 -84 -23   31   53  ...  -277  -211    18
# 4563  4564   33 -132 -103  142 -115 -60  82   97  -29  ...  -220  -206  -130
# 54      55  129 -167 -145   22 -117  -8  57 -170  -39  ...   -61    -4    23
# 5679  5680   31  -96 -119   97 -116  69  84  -25  -33  ...  -211  -156  -133
#
#       f161  f162  f163  f164  f165  f166  new2
# 6111   133   110   175   -67  -160   -21   147
# 6539   155   131   187   -72  -172    14    13
# 4563    66    51   276   -68  -267   -18   146
# 54     138   277   168   -59  -133    84   213
# 5679    32    37   312   -63  -306    -5   147
#
# [5 rows x 168 columns]
